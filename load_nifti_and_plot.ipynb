# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nibabel as nib
import matplotlib.pyplot as plt

data = nib.load('/content/drive/MyDrive/IBMB/nifti/980505831101.nii.gz')
plt.imshow(data.get_fdata()[:,:,0])  #to show the 1st slice
print(data.shape)
# Out:
# (212, 256, 18)
