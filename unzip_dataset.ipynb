# %%
#connect to google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip -q '/content/drive/My Drive/NBML MR Images/IBMB Dataset.zip' -d '/content/drive/My Drive/IBMB'
